# %% [markdown]
# # Silero Vad实时检测与实时可视化显示
#
# 一个简单的笔记本，使用 pyaudio 获取麦克风音频并将该音频馈送到 Silero VAD。
# 我创建它作为一个示例，说明如何将流中的二进制数据输入到 Silero VAD 中。
# 已在 Ubuntu 21.04 (x86) 上进行测试。安装以下依赖项后，无需进行其他设置。
# 该笔记本无法在 google colab 中使用！仅供本地使用。
#
# 来源：https://github.com/snakers4/silero-vad/tree/d5b52843f79c97810940534f3433e162470af83d/examples/pyaudio-streaming

# %%
# !pip install pyaudio jupyterplot

# %%
import io
import numpy as np
import torch
torch.set_num_threads(1)
import torchaudio
import matplotlib
import matplotlib.pylab as plt
import pyaudio

# %%
model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad',
                              model='silero_vad',
                              force_reload=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/code/jupyter-lab/.venv/lib/python3.13/site-packages/torch/hub.py:204, in _validate_not_a_forked_repo(repo_owner, repo_name, ref)
#     203 try:
# --> 204     response = json.loads(_read_url(Request(url, headers=headers)))
#     205 except HTTPError:
#     206     # Retry without token in case it had insufficient permissions.
#
# File ~/code/jupyter-lab/.venv/lib/python3.13/site-packages/torch/hub.py:185, in _read_url(url)
#     184 def _read_url(url):
# --> 185     with urlopen(url) as r:
#     186         return r.read().decode(r.headers.get_content_charset("utf-8"))
#
# File ~/.local/share/uv/python/cpython-3.13.9-macos-aarch64-none/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# ...

# %%
(get_speech_timestamps,
 save_audio,
 read_audio,
 VADIterator,
 collect_chunks) = utils

# %%
# Taken from utils_vad.py
def validate(model,
             inputs: torch.Tensor):
    with torch.no_grad():
        outs = model(inputs)
    return outs

# Provided by Alexander Veysov
def int2float(sound):
    abs_max = np.abs(sound).max()
    sound = sound.astype('float32')
    if abs_max > 0:
        sound *= 1/32768
    sound = sound.squeeze()  # depends on the use case
    return sound

# %%
FORMAT = pyaudio.paInt16
CHANNELS = 1
SAMPLE_RATE = 16000
CHUNK = int(SAMPLE_RATE / 10)

audio = pyaudio.PyAudio()

# %%
# 以下示例从麦克风读取音频作为 250ms 块，将它们转换为 Pytorch 张量，并获取模型认为该帧是有声的概率/置信度。

num_samples = 512

stream = audio.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=SAMPLE_RATE,
                    input=True,
                    frames_per_buffer=CHUNK)
data = []
voiced_confidences = []

frames_to_record = 50

print("Started Recording")
for i in range(0, frames_to_record):
    
    audio_chunk = stream.read(num_samples)
    
    # in case you want to save the audio later
    data.append(audio_chunk)
    
    audio_int16 = np.frombuffer(audio_chunk, np.int16);

    audio_float32 = int2float(audio_int16)
    
    # get the confidences and add them to the list to plot them later
    new_confidence = model(torch.from_numpy(audio_float32), 16000).item()
    voiced_confidences.append(new_confidence)

stream.stop_stream()
stream.close()
print("Stopped the recording")

# plot the confidences for the speech
plt.figure(figsize=(20,6))
plt.plot(voiced_confidences)
plt.show()

# %% [markdown]
# ## 实时可视化

# %%
from jupyterplot import ProgressPlot
import threading
import time

continue_recording = True

def stop():
    input("Press Enter to stop the recording:")
    global continue_recording
    continue_recording = False
    time.sleep(3)
    stream.stop_stream()
    stream.close()
    audio.terminate()

def start_recording():
    
    stream = audio.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=SAMPLE_RATE,
                    input=True,
                    frames_per_buffer=CHUNK)

    data = []
    voiced_confidences = []
    
    global continue_recording
    continue_recording = True
    
    pp = ProgressPlot(plot_names=["Silero VAD"],line_names=["speech probabilities"], x_label="audio chunks")
    global stop_listener
    stop_listener = threading.Thread(target=stop)
    stop_listener.start()

    while continue_recording:
    
        audio_chunk = stream.read(num_samples)
    
        # in case you want to save the audio later
        data.append(audio_chunk)
    
        audio_int16 = np.frombuffer(audio_chunk, np.int16);

        audio_float32 = int2float(audio_int16)
    
        # get the confidences and add them to the list to plot them later
        new_confidence = model(torch.from_numpy(audio_float32), 16000).item()
        voiced_confidences.append(new_confidence)
    
        pp.update(new_confidence)


    pp.finalize()

# %%
start_recording()
stop_listener.join()
